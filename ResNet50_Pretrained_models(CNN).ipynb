# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishekmishra-bareilly/Deep-Learning/blob/main/ResNet50_Pretrained_models(CNN).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input,decode_predictions
import keras
import matplotlib.pyplot as plt
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, Flatten
from tensorflow.keras.preprocessing import image

# %%
# Model bulding
model = ResNet50(weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102967424/102967424 [==============================] - 0s 0us/step

# %%
img_path = '/content/main-qimg-113b395e85852f8e267ca17fc59a5889-lq.jpg'
img = image.load_img(img_path,target_size=(224,224))

# Input image
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7FA9FFC142E0>

# %%
x= image.img_to_array(img)
x = np.expand_dims(x,axis=0)
x = preprocess_input(x)

# %%
# Model predictions
pred = model.predict(x)
print('predicted:', decode_predictions(pred, top=3)[0])
# Out:
# 1/1 [==============================] - 0s 191ms/step
# predicted: [('n02786058', 'Band_Aid', 0.9882442), ('n04116512', 'rubber_eraser', 0.0014744094), ('n04372370', 'switch', 0.0013932656)]
